# %% [markdown]
# What is Streamlit?
# A Python framework to create interactive web apps.
# Mostly used for Data Science, Machine Learning, AI dashboards.
# You don’t need HTML, CSS, or JavaScript.
# Just write Python code and it becomes a web app.
#
# 📌 Example uses:
#
# ML model demo
# Data dashboard
# Visualization tools
# AI chatbot interface
